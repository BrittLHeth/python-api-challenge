# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key
print(weather_api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# 1335c4470289b65e7bbb5459b399e92e

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['ushuaia',
#  'rikitea',
#  'clyde river',
#  'visby',
#  'el balyana',
#  'budhlada',
#  'saskylakh',
#  'chara',
#  'yagunovskiy',
#  'port alfred',
#  'ipixuna',
#  'butaritari',
#  'geraldton',
#  'albany',
#  'hobart',
#  'kwekwe',
#  'busselton',
#  'kapaa',
#  'castro',
#  'east london',
#  'vestmannaeyjar',
#  'victoria',
#  'hermanus',
#  'bluff',
#  'tauramena',
#  'tuktoyaktuk',
#  'bambous virieux',
#  'salta',
#  'veraval',
#  'iqaluit',
#  'port elizabeth',
#  'hithadhoo',
#  'qaanaaq',
#  'methoni',
#  'barrow',
#  'punta arenas',
#  'tura',
#  'vaini',
#  'zhigansk',
#  'maceio',
#  'yellowknife',
#  'barentsburg',
#  'provideniya',
#  'kaeng khoi',
#  'mayo',
#  'sanlucar de barrameda',
#  'lebu',
#  'jamestown',
#  'samalaeulu',
#  'norman wells',
#  'cayenne',
#  'illoqqortoormiut',
#  'bredasdorp',
#  'georgetown',
#  'carnarvon',
#  'vardo',
#  'kemin',
#  'mataura',
#  'upernavik',
#  'de aar',
#  'zaysan',
#  'covington',
#  'pangnirtung',
#  'thompson',
#  'rafai',
#  'saint-philippe',
#  'juneau',
#  'riberalta',
#  'cape town',
#  'awbari',
#  'hilo',
#  'mahebourg',
#  'chuy',
#  'belushya guba',
#  'severo-kurilsk',
#  'mago',
#  'biak',
#  'gidam',
#  'petrolina',
#  'rungata',
#  'grand river south east',
#  'new norfolk',
#  'puerto ayora',
#  'straumen',
#  'bethel',
#  'ponta do sol',
#  'chapais',
#  'san patricio',
#  'hasaki',
#  'nikolskoye',
#  'maneadero',
#  'kodiak',
#  'jalu',
#  'mar del plata',
#  'snezhnogorsk',
#  'khatanga',
#  'port macquarie',
#  'sambava',
#  'avarua',
#  'mineiros',
#  'chokurdakh',
#  'pevek',
#  'taolanaro',
#  'makarov',
#  'omboue',
#  'kangaatsiaq',
#  'vung tau',
#  'port hardy',
#  'tuatapere',
#  'bajna',
#  'salalah',
#  'petropavlovsk-kamchatskiy',
#  'camacupa',
#  'tottori',
#  'olinda',
#  'pyshchug',
#  'bikaner',
#  'korla',
#  'deogarh',
#  'miraflores',
#  'hualmay',
#  'valparaiso',
#  'airai',
#  'broome',
#  'dikson',
#  'mujiayingzi',
#  'bogovarovo',
#  'itupiranga',
#  'marawi',
#  'tsihombe',
#  'carnot',
#  'sisimiut',
#  'catuday',
#  'ribeira grande',
#  'toliary',
#  'mao',
#  'carutapera',
#  'presidencia roque saenz pena',
#  'tyler',
#  'lagoa',
#  'torbay',
#  'puerto carreno',
#  'buribay',
#  'winnemucca',
#  'longyearbyen',
#  'bengkulu',
#  'atuona',
#  'pottsville',
#  'cabo san lucas',
#  'yatou',
#  'ulaanbaatar',
#  'kamaishi',
#  'huangpi',
#  'inhambane',
#  'urubamba',
#  'daru',
#  'olafsvik',
#  'oriximina',
#  'bonavista',
#  'el sauzal',
#  'mys shmidta',
#  'brae',
#  'los llanos de aridane',
#  'cherskiy',
#  'himora',
#  'ardatov',
#  'kirgiz-miyaki',
#  'hun',
#  'jinxiang',
#  'muros',
#  'kavieng',
#  'loukhi',
#  'yerbogachen',
#  'aberdeen',
#  'half moon bay',
#  'san juan de las huertas',
#  'lindas',
#  'ruatoria',
#  'cockburn harbour',
#  'naze',
#  'anzio',
#  'kargasok',
#  'tornio',
#  'esperance',
#  'macas',
#  'codrington',
#  'narsaq',
#  'tasiilaq',
#  'vanavara',
#  'sola',
#  'belle fourche',
#  'santa isabel',
#  'pisco',
#  'vammala',
#  'calbuco',
#  'jieshi',
#  'moses lake',
#  'walvis bay',
#  'moose factory',
#  'finnsnes',
#  'rudolfov',
#  'dawlatabad',
#  'vostok',
#  'inongo',
#  'mashhad',
#  'palu',
#  'dhidhdhoo',
#  'nzega',
#  'urubicha',
#  'labuhan',
#  'luga',
#  'sentyabrskiy',
#  'talnakh',
#  'saleaula',
#  'kiama',
#  'sol-iletsk',
#  'dzhusaly',
#  'margate',
#  'nizhneyansk',
#  'gazli',
#  'kashira',
#  'dicabisagan',
#  'rumuruti',
#  'almeirim',
#  'mutsu',
#  'kununurra',
#  'kedrovyy',
#  'paamiut',
#  'abu samrah',
#  'kharan',
#  'dekar',
#  'matagami',
#  'spanaway',
#  'sitka',
#  'camacha',
#  'barbar',
#  'nicoya',
#  'the valley',
#  'resavica',
#  'bhubaneswar',
#  'amontada',
#  'vila franca do campo',
#  'padang',
#  'sao filipe',
#  'mutis',
#  'grindavik',
#  'bayan',
#  'plettenberg bay',
#  'sambo creek',
#  'tigzirt',
#  'ciudad bolivar',
#  'arraial do cabo',
#  'aliwal north',
#  'rapid valley',
#  'manacapuru',
#  'iralaya',
#  'lock haven',
#  'carbonia',
#  'misratah',
#  'isangel',
#  'te anau',
#  'itarema',
#  'gao',
#  'fairbanks',
#  'tateyama',
#  'nibong tebal',
#  'palabuhanratu',
#  'labutta',
#  'mponela',
#  'amderma',
#  'otradnoye',
#  'meyungs',
#  'bathsheba',
#  'nanortalik',
#  'okhotsk',
#  'banjar',
#  'winburg',
#  'west monroe',
#  'sinnamary',
#  'tay ninh',
#  'yerofey pavlovich',
#  'villazon',
#  'deskati',
#  'evensk',
#  'aguimes',
#  'hovd',
#  'vila velha',
#  'yabelo',
#  'saint george',
#  'san lawrenz',
#  'lumeje',
#  'hambantota',
#  'albury',
#  'roskovec',
#  'san cristobal',
#  'marcona',
#  'alugan',
#  'anadyr',
#  'marystown',
#  'kazalinsk',
#  'saint-francois',
#  'ponta delgada',
#  'kysyl-syr',
#  'tiksi',
#  'taltal',
#  'bunol',
#  'saldanha',
#  'ilulissat',
#  'morehead',
#  'serebryanyy bor',
#  'ust-nera',
#  'sinegorye',
#  'zabid',
#  'kalengwa',
#  'condado',
#  'havre-saint-pierre',
#  'wismar',
#  'waddan',
#  'rio gallegos',
#  'dwarka',
#  'aswan',
#  'pilar',
#  'kruisfontein',
#  'strezhevoy',
#  'barawe',
#  'portland',
#  'road town',
#  'invermere',
#  'gallup',
#  'la palma',
#  'laguna',
#  'kaitangata',
#  'mount isa',
#  'guilin',
#  'coquimbo',
#  'imeni poliny osipenko',
#  'gataia',
#  'kahului',
#  'tiznit',
#  'birin',
#  'seaford',
#  'kenai',
#  'abha',
#  'tari',
#  'haines junction',
#  'algiers',
#  'cape elizabeth',
#  'presque isle',
#  'darhan',
#  'pangai',
#  'nabinagar',
#  'flin flon',
#  'berbera',
#  'kokopo',
#  'charters towers',
#  'konosha',
#  'skalistyy',
#  'maloshuyka',
#  'bom jesus',
#  'tsentralnyy',
#  'dabat',
#  'tahta',
#  'lichinga',
#  'luderitz',
#  'nabire',
#  'isilkul',
#  'avera',
#  'magalia',
#  'callaway',
#  'flinders',
#  'constitucion',
#  'yenagoa',
#  'amahai',
#  'puerto el triunfo',
#  'tabiauea',
#  'ananas',
#  'ingraj bazar',
#  'bathurst',
#  'mahaicony',
#  'santa maria',
#  'saint anthony',
#  'kamenskoye',
#  'caceres',
#  'tome-acu',
#  'praia da vitoria',
#  'aksha',
#  'davila',
#  'black river',
#  'tagusao',
#  'zhezkazgan',
#  'cidreira',
#  'shupiyan',
#  'kismayo',
#  'luganville',
#  'karratha',
#  'ialibu',
#  'gizo',
#  'sulangan',
#  'necochea',
#  'rizhao',
#  'charyshskoye',
#  'christchurch',
#  'bubaque',
#  'pacific grove',
#  'timiryazevskiy',
#  'deputatskiy',
#  'ketchikan',
#  'ancud',
#  'nome',
#  'mogadishu',
#  'kichmengskiy gorodok',
#  'billings',
#  'itabera',
#  'bitkine',
#  'port-gentil',
#  'san policarpo',
#  'umzimvubu',
#  'nigran',
#  'nobres',
#  'tanout',
#  'goranboy',
#  'borazjan',
#  'prince rupert',
#  'mouzakion',
#  'trincomalee',
#  'san quintin',
#  'port pirie',
#  'samana',
#  'taga',
#  'chumikan',
#  'taoudenni',
#  'tahoua',
#  'katsuura',
#  'shahr-e kord',
#  'tautira',
#  'gorom-gorom',
#  'dinguiraye',
#  'kuito',
#  'tunduru',
#  'karkaralinsk',
#  'gorno-chuyskiy',
#  'puerto princesa',
#  'camana',
#  'sawasawa',
#  'jutai',
#  'haibowan',
#  'roebourne',
#  'kibala',
#  'beni',
#  'imbituba',
#  'wonthaggi',
#  'santa luzia',
#  'cumpas',
#  'jeremoabo',
#  'dolbeau',
#  'fortuna',
#  'faya',
#  'urozhaynoye',
#  'viedma',
#  'warqla',
#  'ust-kamchatsk',
#  'jiuquan',
#  'gat',
#  'faanui',
#  'alagoinhas',
#  'khrystynivka',
#  'kendari',
#  'natalio',
#  'bardiyah',
#  'salinopolis',
#  'koson',
#  'pinhao',
#  'kizukuri',
#  'honiara',
#  'attawapiskat',
#  'kabare',
#  'bangkalan',
#  'leningradskiy',
#  'tecpan',
#  'micheweni',
#  'touros',
#  'mama',
#  'outjo',
#  'vestmanna',
#  'ambulu',
#  'chiang khong',
#  'beyneu',
#  'arlit',
#  'lezajsk',
#  'along',
#  'hopkinton',
#  'limoeiro do ajuru',
#  'brownsville',
#  'zyryanskoye',
#  'wainwright',
#  'kudat',
#  'san miguel',
#  'saint-junien',
#  'altay',
#  'pangody',
#  'soyo',
#  'phan rang',
#  'sur',
#  'isla vista',
#  'kharitonovo',
#  'kirkland lake',
#  'sangar',
#  'cape coast',
#  'khanewal',
#  'nyagan',
#  'sangmelima',
#  'port lincoln',
#  'andra',
#  'zlatoustovsk',
#  'oga',
#  'san jose',
#  'lavrentiya',
#  'yar-sale',
#  'dunedin',
#  'pringsewu',
#  'el mahalla el kubra',
#  'siyabuswa',
#  'solnechnyy',
#  'getashen',
#  'berlevag',
#  'guerrero negro',
#  'liverpool',
#  'mahina',
#  'dembi dolo',
#  'kisangani',
#  'solovetskiy',
#  'solenzo',
#  'lompoc',
#  'casper',
#  'teguldet',
#  'jakar',
#  'timizart',
#  'mount gambier',
#  'srednekolymsk',
#  'dubbo',
#  'malkara',
#  'bulaevo',
#  'zyryanka',
#  'batticaloa',
#  'oranjemund',
#  'kirkwood',
#  'marigot',
#  'bilibino',
#  'tumannyy',
#  'lewiston',
#  'klaksvik',
#  'champerico',
#  'tual',
#  'nefteyugansk',
#  'tezu',
#  'helong',
#  'isiro',
#  'eyl',
#  'san francisco del rincon',
#  'juchipila',
#  'lake charles',
#  'ha tinh',
#  'platon sanchez',
#  'whitecourt',
#  'moerai',
#  'flagstaff',
#  'riyadh',
#  'montrose',
#  'tahe',
#  'goundam',
#  'emerald',
#  'sapa',
#  'bure',
#  'urusha',
#  'artyk',
#  'ahipara',
#  'conakry',
#  'lamar',
#  'fort nelson',
#  'monrovia',
#  'changtu',
#  'villa carlos paz',
#  'atar',
#  'ouadda',
#  'waingapu',
#  'richards bay',
#  'aviemore',
#  'beringovskiy',
#  'vaitupu',
#  'souillac',
#  'madridejos',
#  'kenitra',
#  'pangoa',
#  'sao felix do xingu',
#  'gualeguay',
#  'namie',
#  'mackay',
#  'uarini',
#  'hay river',
#  'rawson',
#  'omsukchan',
#  'galesong',
#  'worland',
#  'chicama',
#  'talcahuano',
#  'lazaro cardenas',
#  'claresholm',
#  'san carlos de bariloche',
#  'bababe',
#  'yumen',
#  'key west',
#  'baykit',
#  'colares',
#  'hihifo',
#  'ouro preto do oeste',
#  'amarante do maranhao',
#  'roma']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
#api call - api.openweathermap.org/data/2.5/weather?q={city name}&appid={your api key}

url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
query_url = url + "&q="
#print(query_url)


# 4 pieces of info to get
temp = []
humidity = []
cloudiness = []
wind_speed = []
weather_dict = []


#need to loop through your cities to gather info from each one and put that into a df
for city in cities: 
    try:
        response = requests.get(query_url + city + "&appid=1335c4470289b65e7bbb5459b399e92e").json()
        weather_dict.append({
                        "city": city,
                        "latitude": response['coord']['lat'],
                        "longitude": response['coord']['lon'],
                        "temperature": response['main']['temp'],
                        "humidity": response['main']['humidity'],
                        "cloudiness": response['clouds']['all'],
                        "wind speed": response['clouds']['all']
        })
        #print(weather_dict)
        print(f'City number {number} of {len(cities)}. | {city}')
    except:
        print("No data for", city)
    
# sayat = f"{url}q=sayat&appid={weather_api_key}"
# print(sayat)
# sayat_response = requests.get(sayat)
# sayat_response.json()

#json.dumps(response, indent=4, sort_keys=True)
# Out:
# No data for ushuaia
# No data for rikitea
# No data for clyde river
# No data for visby
# No data for el balyana
# No data for budhlada
# No data for saskylakh
# No data for chara
# No data for yagunovskiy
# No data for port alfred
# No data for ipixuna
# No data for butaritari
# No data for geraldton
# No data for albany
# No data for hobart
# No data for kwekwe
# No data for busselton
# No data for kapaa
# No data for castro
# No data for east london
# No data for vestmannaeyjar
# No data for victoria
# No data for hermanus
# No data for bluff
# No data for tauramena
# No data for tuktoyaktuk
# No data for bambous virieux
# No data for salta
# No data for veraval
# No data for iqaluit
# No data for port elizabeth
# No data for hithadhoo
# No data for qaanaaq
# No data for methoni
# No data for barrow
# No data for punta arenas
# No data for tura
# No data for vaini
# No data for zhigansk
# No data for maceio
# No data for yellowknife
# No data for barentsburg
# No data for provideniya
# No data for kaeng khoi
# No data for mayo
# No data for sanlucar de barrameda
# No data for lebu
# No data for jamestown
# No data for samalaeulu
# No data for norman wells
# No data for cayenne
# No data for illoqqortoormiut
# No data for bredasdorp
# No data for georgetown
# No data for carnarvon
# No data for vardo
# No data for kemin
# No data for mataura
# No data for upernavik
# No data for de aar
# No data for zaysan
# No data for covington
# No data for pangnirtung
# No data for thompson
# No data for rafai
# No data for saint-philippe
# No data for juneau
# No data for riberalta
# No data for cape town
# No data for awbari
# No data for hilo
# No data for mahebourg
# No data for chuy
# No data for belushya guba
# No data for severo-kurilsk
# No data for mago
# No data for biak
# No data for gidam
# No data for petrolina
# No data for rungata
# No data for grand river south east
# No data for new norfolk
# No data for puerto ayora
# No data for straumen
# No data for bethel
# No data for ponta do sol
# No data for chapais
# No data for san patricio
# No data for hasaki
# No data for nikolskoye
# No data for maneadero
# No data for kodiak
# No data for jalu
# No data for mar del plata
# No data for snezhnogorsk
# No data for khatanga
# No data for port macquarie
# No data for sambava
# No data for avarua
# No data for mineiros
# No data for chokurdakh
# No data for pevek
# No data for taolanaro
# No data for makarov
# No data for omboue
# No data for kangaatsiaq
# No data for vung tau
# No data for port hardy
# No data for tuatapere
# No data for bajna
# No data for salalah
# No data for petropavlovsk-kamchatskiy
# No data for camacupa
# No data for tottori
# No data for olinda
# No data for pyshchug
# No data for bikaner
# No data for korla
# No data for deogarh
# No data for miraflores
# No data for hualmay
# No data for valparaiso
# No data for airai
# No data for broome
# No data for dikson
# No data for mujiayingzi
# No data for bogovarovo
# No data for itupiranga
# No data for marawi
# No data for tsihombe
# No data for carnot
# No data for sisimiut
# No data for catuday
# No data for ribeira grande
# No data for toliary
# No data for mao
# No data for carutapera
# No data for presidencia roque saenz pena
# No data for tyler
# No data for lagoa
# No data for torbay
# No data for puerto carreno
# No data for buribay
# No data for winnemucca
# No data for longyearbyen
# No data for bengkulu
# No data for atuona
# No data for pottsville
# No data for cabo san lucas
# No data for yatou
# No data for ulaanbaatar
# No data for kamaishi
# No data for huangpi
# No data for inhambane
# No data for urubamba
# No data for daru
# No data for olafsvik
# No data for oriximina
# No data for bonavista
# No data for el sauzal
# No data for mys shmidta
# No data for brae
# No data for los llanos de aridane
# No data for cherskiy
# No data for himora
# No data for ardatov
# No data for kirgiz-miyaki
# No data for hun
# No data for jinxiang
# No data for muros
# No data for kavieng
# No data for loukhi
# No data for yerbogachen
# No data for aberdeen
# No data for half moon bay
# No data for san juan de las huertas
# No data for lindas
# No data for ruatoria
# No data for cockburn harbour
# No data for naze
# No data for anzio
# No data for kargasok
# No data for tornio
# No data for esperance
# No data for macas
# No data for codrington
# No data for narsaq
# No data for tasiilaq
# No data for vanavara
# No data for sola
# No data for belle fourche
# No data for santa isabel
# No data for pisco
# No data for vammala
# No data for calbuco
# No data for jieshi
# No data for moses lake
# No data for walvis bay
# No data for moose factory
# No data for finnsnes
# No data for rudolfov
# No data for dawlatabad
# No data for vostok
# No data for inongo
# No data for mashhad
# No data for palu
# No data for dhidhdhoo
# No data for nzega
# No data for urubicha
# No data for labuhan
# No data for luga
# No data for sentyabrskiy
# No data for talnakh
# No data for saleaula
# No data for kiama
# No data for sol-iletsk
# No data for dzhusaly
# No data for margate
# No data for nizhneyansk
# No data for gazli
# No data for kashira
# No data for dicabisagan
# No data for rumuruti
# No data for almeirim
# No data for mutsu
# No data for kununurra
# No data for kedrovyy
# No data for paamiut
# No data for abu samrah
# No data for kharan
# No data for dekar
# No data for matagami
# No data for spanaway
# No data for sitka
# No data for camacha
# No data for barbar
# No data for nicoya
# No data for the valley
# No data for resavica
# No data for bhubaneswar
# No data for amontada
# No data for vila franca do campo
# No data for padang
# No data for sao filipe
# No data for mutis
# No data for grindavik
# No data for bayan
# No data for plettenberg bay
# No data for sambo creek
# No data for tigzirt
# No data for ciudad bolivar
# No data for arraial do cabo
# No data for aliwal north
# No data for rapid valley
# No data for manacapuru
# No data for iralaya
# No data for lock haven
# No data for carbonia
# No data for misratah
# No data for isangel
# No data for te anau
# No data for itarema
# No data for gao
# No data for fairbanks
# No data for tateyama
# No data for nibong tebal
# No data for palabuhanratu
# No data for labutta
# No data for mponela
# No data for amderma
# No data for otradnoye
# No data for meyungs
# No data for bathsheba
# No data for nanortalik
# No data for okhotsk
# No data for banjar
# No data for winburg
# No data for west monroe
# No data for sinnamary
# No data for tay ninh
# No data for yerofey pavlovich
# No data for villazon
# No data for deskati
# No data for evensk
# No data for aguimes
# No data for hovd
# No data for vila velha
# No data for yabelo
# No data for saint george
# No data for san lawrenz
# No data for lumeje
# No data for hambantota
# No data for albury
# No data for roskovec
# No data for san cristobal
# No data for marcona
# No data for alugan
# No data for anadyr
# No data for marystown
# No data for kazalinsk
# No data for saint-francois
# No data for ponta delgada
# No data for kysyl-syr
# No data for tiksi
# No data for taltal
# No data for bunol
# No data for saldanha
# No data for ilulissat
# No data for morehead
# No data for serebryanyy bor
# No data for ust-nera
# No data for sinegorye
# No data for zabid
# No data for kalengwa
# No data for condado
# No data for havre-saint-pierre
# No data for wismar
# No data for waddan
# No data for rio gallegos
# No data for dwarka
# No data for aswan
# No data for pilar
# No data for kruisfontein
# No data for strezhevoy
# No data for barawe
# No data for portland
# No data for road town
# No data for invermere
# No data for gallup
# No data for la palma
# No data for laguna
# No data for kaitangata
# No data for mount isa
# No data for guilin
# No data for coquimbo
# No data for imeni poliny osipenko
# No data for gataia
# No data for kahului
# No data for tiznit
# No data for birin
# No data for seaford
# No data for kenai
# No data for abha
# No data for tari
# No data for haines junction
# No data for algiers
# No data for cape elizabeth
# No data for presque isle
# No data for darhan
# No data for pangai
# No data for nabinagar
# No data for flin flon
# No data for berbera
# No data for kokopo
# No data for charters towers
# No data for konosha
# No data for skalistyy
# No data for maloshuyka
# No data for bom jesus
# No data for tsentralnyy
# No data for dabat
# No data for tahta
# No data for lichinga
# No data for luderitz
# No data for nabire
# No data for isilkul
# No data for avera
# No data for magalia
# No data for callaway
# No data for flinders
# No data for constitucion
# No data for yenagoa
# No data for amahai
# No data for puerto el triunfo
# No data for tabiauea
# No data for ananas
# No data for ingraj bazar
# No data for bathurst
# No data for mahaicony
# No data for santa maria
# No data for saint anthony
# No data for kamenskoye
# No data for caceres
# No data for tome-acu
# No data for praia da vitoria
# No data for aksha
# No data for davila
# No data for black river
# No data for tagusao
# No data for zhezkazgan
# No data for cidreira
# No data for shupiyan
# No data for kismayo
# No data for luganville
# No data for karratha
# No data for ialibu
# No data for gizo
# No data for sulangan
# No data for necochea
# No data for rizhao
# No data for charyshskoye
# No data for christchurch
# No data for bubaque
# No data for pacific grove
# No data for timiryazevskiy
# No data for deputatskiy
# No data for ketchikan
# No data for ancud
# No data for nome
# No data for mogadishu
# No data for kichmengskiy gorodok
# No data for billings
# No data for itabera
# No data for bitkine
# No data for port-gentil
# No data for san policarpo
# No data for umzimvubu
# No data for nigran
# No data for nobres
# No data for tanout
# No data for goranboy
# No data for borazjan
# No data for prince rupert
# No data for mouzakion
# No data for trincomalee
# No data for san quintin
# No data for port pirie
# No data for samana
# No data for taga
# No data for chumikan
# No data for taoudenni
# No data for tahoua
# No data for katsuura
# No data for shahr-e kord
# No data for tautira
# No data for gorom-gorom
# No data for dinguiraye
# No data for kuito
# No data for tunduru
# No data for karkaralinsk
# No data for gorno-chuyskiy
# No data for puerto princesa
# No data for camana
# No data for sawasawa
# No data for jutai
# No data for haibowan
# No data for roebourne
# No data for kibala
# No data for beni
# No data for imbituba
# No data for wonthaggi
# No data for santa luzia
# No data for cumpas
# No data for jeremoabo
# No data for dolbeau
# No data for fortuna
# No data for faya
# No data for urozhaynoye
# No data for viedma
# No data for warqla
# No data for ust-kamchatsk
# No data for jiuquan
# No data for gat
# No data for faanui
# No data for alagoinhas
# No data for khrystynivka
# No data for kendari
# No data for natalio
# No data for bardiyah
# No data for salinopolis
# No data for koson
# No data for pinhao
# No data for kizukuri
# No data for honiara
# No data for attawapiskat
# No data for kabare
# No data for bangkalan
# No data for leningradskiy
# No data for tecpan
# No data for micheweni
# No data for touros
# No data for mama
# No data for outjo
# No data for vestmanna
# No data for ambulu
# No data for chiang khong
# No data for beyneu
# No data for arlit
# No data for lezajsk
# No data for along
# No data for hopkinton
# No data for limoeiro do ajuru
# No data for brownsville
# No data for zyryanskoye
# No data for wainwright
# No data for kudat
# No data for san miguel
# No data for saint-junien
# No data for altay
# No data for pangody
# No data for soyo
# No data for phan rang
# No data for sur
# No data for isla vista
# No data for kharitonovo
# No data for kirkland lake
# No data for sangar
# No data for cape coast
# No data for khanewal
# No data for nyagan
# No data for sangmelima
# No data for port lincoln
# No data for andra
# No data for zlatoustovsk
# No data for oga
# No data for san jose
# No data for lavrentiya
# No data for yar-sale
# No data for dunedin
# No data for pringsewu
# No data for el mahalla el kubra
# No data for siyabuswa
# No data for solnechnyy
# No data for getashen
# No data for berlevag
# No data for guerrero negro
# No data for liverpool
# No data for mahina
# No data for dembi dolo
# No data for kisangani
# No data for solovetskiy
# No data for solenzo
# No data for lompoc
# No data for casper
# No data for teguldet
# No data for jakar
# No data for timizart
# No data for mount gambier
# No data for srednekolymsk
# No data for dubbo
# No data for malkara
# No data for bulaevo
# No data for zyryanka
# No data for batticaloa
# No data for oranjemund
# No data for kirkwood
# No data for marigot
# No data for bilibino
# No data for tumannyy
# No data for lewiston
# No data for klaksvik
# No data for champerico
# No data for tual
# No data for nefteyugansk
# No data for tezu
# No data for helong
# No data for isiro
# No data for eyl
# No data for san francisco del rincon
# No data for juchipila
# No data for lake charles
# No data for ha tinh
# No data for platon sanchez
# No data for whitecourt
# No data for moerai
# No data for flagstaff
# No data for riyadh
# No data for montrose
# No data for tahe
# No data for goundam
# No data for emerald
# No data for sapa
# No data for bure
# No data for urusha
# No data for artyk
# No data for ahipara
# No data for conakry
# No data for lamar
# No data for fort nelson
# No data for monrovia
# No data for changtu
# No data for villa carlos paz
# No data for atar
# No data for ouadda
# No data for waingapu
# No data for richards bay
# No data for aviemore
# No data for beringovskiy
# No data for vaitupu
# No data for souillac
# No data for madridejos
# No data for kenitra
# No data for pangoa
# No data for sao felix do xingu
# No data for gualeguay
# No data for namie
# No data for mackay
# No data for uarini
# No data for hay river
# No data for rawson
# No data for omsukchan
# No data for galesong
# No data for worland
# No data for chicama
# No data for talcahuano
# No data for lazaro cardenas
# No data for claresholm
# No data for san carlos de bariloche
# No data for bababe
# No data for yumen
# No data for key west
# No data for baykit
# No data for colares
# No data for hihifo
# No data for ouro preto do oeste
# No data for amarante do maranhao
# No data for roma

# %%
print(weather_dict)
# Out:
# [{'city': 'ushuaia', 'latitude': -54.8, 'longitude': -68.3, 'temperature': 278.15, 'humidity': 56, 'cloudiness': 75, 'wind speed': 75}, {'city': 'rikitea', 'latitude': -23.12, 'longitude': -134.97, 'temperature': 294.04, 'humidity': 77, 'cloudiness': 0, 'wind speed': 0}, {'city': 'clyde river', 'latitude': 70.47, 'longitude': -68.59, 'temperature': 279.92, 'humidity': 68, 'cloudiness': 2, 'wind speed': 2}, {'city': 'visby', 'latitude': 57.64, 'longitude': 18.3, 'temperature': 289.35, 'humidity': 45, 'cloudiness': 0, 'wind speed': 0}, {'city': 'budhlada', 'latitude': 29.93, 'longitude': 75.57, 'temperature': 301.97, 'humidity': 71, 'cloudiness': 8, 'wind speed': 8}, {'city': 'saskylakh', 'latitude': 71.92, 'longitude': 114.08, 'temperature': 284.9, 'humidity': 60, 'cloudiness': 97, 'wind speed': 97}, {'city': 'chara', 'latitude': 56.91, 'longitude': 118.26, 'temperature': 279.76, 'humidity': 72, 'cloudiness': 0, 'wind speed': 0}, {'city': 'yagunovskiy', 'latitude': 55.28, 'longitude': 85.98, 'temperature': 287.15, 'humidity': 82, 'cloudiness': 40, 'wind speed': 40}, {'city': 'port alfred', 'latitude': -33.59, 'longitude': 26.89, 'temperature': 290.01, 'humidity': 72, 'cloudiness': 0, 'wind speed': 0}, {'city': 'ipixuna', 'latitude': -1.76, 'longitude': -48.8, 'temperature': 304.15, 'humidity': 62, 'cloudiness': 40, 'wind speed': 40}, {'city': 'butaritari', 'latitude': 3.07, 'longitude': 172.79, 'temperature': 300.8, 'humidity': 65, 'cloudiness': 77, 'wind speed': 77}, {'city': 'geraldton', 'latitude': -28.77, 'longitude': 114.6, 'temperature': 281.15, 'humidity': 93, 'cloudiness': 0, 'wind speed': 0}, {'city': 'albany', 'latitude': 42.6, 'longitude': -73.97, 'temperature': 300.44, 'humidity': 68, 'cloudiness': 45, 'wind speed': 45}, {'city': 'hobart', 'latitude': -42.88, 'longitude': 147.33, 'temperature': 281.22, 'humidity': 57, 'cloudiness': 100, 'wind speed': 100}, {'city': 'kwekwe', 'latitude': -18.93, 'longitude': 29.81, 'temperature': 291.12, 'humidity': 30, 'cloudiness': 0, 'wind speed': 0}, {'city': 'busselton', 'latitude': -33.65, 'longitude': 115.33, 'temperature': 281.16, 'humidity': 75, 'cloudiness': 43, 'wind speed': 43}, {'city': 'kapaa', 'latitude': 22.08, 'longitude': -159.32, 'temperature': 300.3, 'humidity': 74, 'cloudiness': 20, 'wind speed': 20}, {'city': 'castro', 'latitude': -24.79, 'longitude': -50.01, 'temperature': 290.45, 'humidity': 66, 'cloudiness': 0, 'wind speed': 0}, {'city': 'east london', 'latitude': -33.02, 'longitude': 27.91, 'temperature': 291.15, 'humidity': 88, 'cloudiness': 2, 'wind speed': 2}, {'city': 'vestmannaeyjar', 'latitude': 63.44, 'longitude': -20.27, 'temperature': 285.15, 'humidity': 71, 'cloudiness': 29, 'wind speed': 29}, {'city': 'victoria', 'latitude': 22.29, 'longitude': 114.16, 'temperature': 302.61, 'humidity': 79, 'cloudiness': 100, 'wind speed': 100}, {'city': 'hermanus', 'latitude': -34.42, 'longitude': 19.23, 'temperature': 287.04, 'humidity': 91, 'cloudiness': 100, 'wind speed': 100}, {'city': 'bluff', 'latitude': -46.6, 'longitude': 168.33, 'temperature': 280.37, 'humidity': 72, 'cloudiness': 96, 'wind speed': 96}, {'city': 'tauramena', 'latitude': 5.02, 'longitude': -72.75, 'temperature': 298.82, 'humidity': 83, 'cloudiness': 95, 'wind speed': 95}, {'city': 'tuktoyaktuk', 'latitude': 69.45, 'longitude': -133.04, 'temperature': 280.15, 'humidity': 100, 'cloudiness': 90, 'wind speed': 90}, {'city': 'bambous virieux', 'latitude': -20.34, 'longitude': 57.76, 'temperature': 294.47, 'humidity': 83, 'cloudiness': 40, 'wind speed': 40}, {'city': 'salta', 'latitude': -24.79, 'longitude': -65.41, 'temperature': 302.15, 'humidity': 14, 'cloudiness': 40, 'wind speed': 40}, {'city': 'veraval', 'latitude': 20.9, 'longitude': 70.37, 'temperature': 300.59, 'humidity': 84, 'cloudiness': 100, 'wind speed': 100}, {'city': 'iqaluit', 'latitude': 63.75, 'longitude': -68.51, 'temperature': 283.92, 'humidity': 62, 'cloudiness': 75, 'wind speed': 75}, {'city': 'port elizabeth', 'latitude' ...

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#           city  latitude  longitude  temperature  humidity  cloudiness  \
# 0      ushuaia    -54.80     -68.30       278.15        56          75
# 1      rikitea    -23.12    -134.97       294.04        77           0
# 2  clyde river     70.47     -68.59       279.92        68           2
# 3        visby     57.64      18.30       289.35        45           0
# 4     budhlada     29.93      75.57       301.97        71           8
#
#    wind speed
# 0          75
# 1           0
# 2           2
# 3           0
# 4           8

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
#weather_dict = {
    "city": cities,
    "lat": latitude    
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed
}
#weather_data = pd.DataFrame(weather_dict)
#weather_data.head()
# Out:
#   File "<ipython-input-7-2aee6894cfb8>", line 3
#     "city": cities,
#     ^
# IndentationError: unexpected indent

# %%
weather_df.to_csv('Weather dataframe')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
for row in weather_df.rows():
    if weather_df["humidity" < 100]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
#  ## Latitude vs. Temperature Plot

# %%
#pd.read_csv('Weather dataframe.csv')

plt.scatter(weather_df["latitude"],weather_df["temperature"], marker="o", alpha = 0.75)

plt.title(f"Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid(True)

plt.show()

plt.savefig("LatvsTemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["latitude"],weather_df["humidity"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.show()

plt.savefig("Latvshumidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["latitude"],weather_df["cloudiness"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.show()

plt.savefig("LatvsCloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["latitude"],weather_df["wind speed"], marker="o", alpha = 0.75)

plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.show()

plt.savefig("LatvsWindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def linear_regress(xdata, ydata, coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)

# Get regression values
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(xdata, ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,coordinates,fontsize=15,color="red")
    
    plt.show()
    

    
# plt.title(f"Latitude vs. Temperature")
# plt.xlabel("Latitude")
# plt.ylabel("Temperature")

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_hemisphere = weather_df.loc[weather_df["latitude"] >= 0.0]
northern_hemisphere.reset_index(inplace=True)

southern_hemisphere = weather_df.loc[weather_df["latitude"] < 0.0]
southern_hemisphere.reset_index(inplace=True)

northern_hemisphere.head()
# Out:
#    index         city  latitude  longitude  temperature  humidity  cloudiness  \
# 0      2  clyde river     70.47     -68.59       279.92        68           2
# 1      3        visby     57.64      18.30       289.35        45           0
# 2      4     budhlada     29.93      75.57       301.97        71           8
# 3      5    saskylakh     71.92     114.08       284.90        60          97
# 4      6        chara     56.91     118.26       279.76        72           0
#
#    wind speed
# 0           2
# 1           0
# 2           8
# 3          97
# 4           0

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xdata = northern_hemisphere['latitude']
ydata = northern_hemisphere['temperature']
plt.title("City Latitude vs. Max Temp in the Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (K)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))

plt.savefig("NH-Lat-vs-temp.png")

# %%
### As you approach the equator, average temperature increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xdata = southern_hemisphere['latitude']
ydata = southern_hemisphere['temperature']
plt.title("City Latitude vs. Max Temp in the Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (K)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))

plt.savefig("SH-Lat-vs-temp.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xdata = northern_hemisphere['latitude']
ydata = northern_hemisphere['humidity']
plt.title("City Latitude vs. Humidity in the Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))
plt.savefig("NH-Lat-vs-hum.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xdata = southern_hemisphere['latitude']
ydata = southern_hemisphere['humidity']
plt.title("City Latitude vs. Humidity in the Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))
plt.savefig("SH-Lat-vs-hum.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xdata = northern_hemisphere['latitude']
ydata = northern_hemisphere['cloudiness']
plt.title("City Latitude vs. Cloudiness in the Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))
plt.savefig("NH-Lat-vs-cloud.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xdata = southern_hemisphere['latitude']
ydata = southern_hemisphere['cloudiness']
plt.title("City Latitude vs. Cloudiness in the Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))
plt.savefig("SH-Lat-vs-cloud.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xdata = southern_hemisphere['latitude']
ydata = southern_hemisphere['wind speed']
plt.title("City Latitude vs. Wind Speed in the Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))
plt.savefig("NH-Lat-vs-wind.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xdata = southern_hemisphere['latitude']
ydata = southern_hemisphere['wind speed']
plt.title("City Latitude vs. Wind Speed in the Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

linear_regress(xdata, ydata, (0,300))
plt.savefig("SH-Lat-vs-wind.png")
